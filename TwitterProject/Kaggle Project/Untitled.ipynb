# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train_twitter.csv')

# %%
df
# Out:
#                  tweet_id airline_sentiment     airline  \
# 0      567900433542488064          negative   Southwest
# 1      569989168903819264          positive   Southwest
# 2      568089179520954368          positive      United
# 3      568928195581513728          negative   Southwest
# 4      568594180014014464          negative      United
# ...                   ...               ...         ...
# 10975  569934458364813313           neutral    American
# 10976  568564006329434113          positive      United
# 10977  569643648910028801          negative  US Airways
# 10978  568864981917110272          negative  US Airways
# 10979  568929299350179840          negative      United
#
#       airline_sentiment_gold           name negativereason_gold  \
# 0                        NaN  ColeyGirouard                 NaN
# 1                        NaN  WalterFaddoul                 NaN
# 2                        NaN      LocalKyle                 NaN
# ...

# %%
trainingData = df.sample(frac = 0.7)

# %%
testData = df.drop(trainingData.index)

# %%
trainingData = trainingData.reset_index()

# %%
trainingData.drop(columns = ['index'], inplace = True)

# %%
trainingData
# Out:
#                 tweet_id airline_sentiment     airline airline_sentiment_gold  \
# 0     569612379811676161          negative  US Airways                    NaN
# 1     570283248301043712          negative   Southwest                    NaN
# 2     569684565838553088          negative    American                    NaN
# 3     569313126342123520          negative  US Airways                    NaN
# 4     569723892358467584          negative      United                    NaN
# ...                  ...               ...         ...                    ...
# 7681  569599532268449792          negative  US Airways                    NaN
# 7682  568475947617411072           neutral  US Airways                    NaN
# 7683  569392511732588544          negative  US Airways                    NaN
# 7684  568675083314552832          positive      United                    NaN
# 7685  568159085356384256          negative      United                    NaN
#
# ...

# %%
testData = testData.reset_index()

# %%
testData.drop(columns = ['index'], inplace = True)

# %%
testData
# Out:
#                 tweet_id airline_sentiment     airline airline_sentiment_gold  \
# 0     567900433542488064          negative   Southwest                    NaN
# 1     569658903044218880          negative       Delta                    NaN
# 2     568542766860541952          positive       Delta                    NaN
# 3     568870144891600896          positive   Southwest                    NaN
# 4     569879497891303424           neutral       Delta                    NaN
# ...                  ...               ...         ...                    ...
# 3289  568118177537744897           neutral   Southwest                    NaN
# 3290  568841631585021952          negative      United                    NaN
# 3291  569262534232039427          negative       Delta                    NaN
# 3292  569369008580874240          negative  US Airways                    NaN
# 3293  567617081336950784          negative   Southwest                    NaN
#
# ...

# %%
testData['airline_sentiment_gold'].unique()
# Out:
# array([nan, 'negative', 'neutral', 'positive'], dtype=object)

# %%
trainingData.to_csv('Train.csv')

# %%
test_data_Y = testData['airline_sentiment']

# %%
testData['']
# Out:
# 0       negative
# 1       negative
# 2       positive
# 3       positive
# 4        neutral
#           ...
# 3289     neutral
# 3290    negative
# 3291    negative
# 3292    negative
# 3293    negative
# Name: airline_sentiment, Length: 3294, dtype: object

# %%
testData.drop(columns = ['airline_sentiment'], inplace = True)

# %%
testData.to_csv('Test.csv')

# %%
test_data_Y.to_csv('correctY.csv')

# %%
testData
# Out:
#                 tweet_id     airline airline_sentiment_gold           name  \
# 0     567900433542488064   Southwest                    NaN  ColeyGirouard
# 1     569658903044218880       Delta                    NaN   aaronkinnari
# 2     568542766860541952       Delta                    NaN    TimothySays
# 3     568870144891600896   Southwest                    NaN         amyums
# 4     569879497891303424       Delta                    NaN      tonymbove
# ...                  ...         ...                    ...            ...
# 3289  568118177537744897   Southwest                    NaN     BobbiStorm
# 3290  568841631585021952      United                    NaN   iamawarplane
# 3291  569262534232039427       Delta                    NaN        rosenrj
# 3292  569369008580874240  US Airways                    NaN    dailylaurel
# 3293  567617081336950784   Southwest                    NaN    mrshossruns
#
#      negativereason_gold  retweet_count  \
# ...

# %%
trainingData
# Out:
#                 tweet_id airline_sentiment     airline airline_sentiment_gold  \
# 0     569612379811676161          negative  US Airways                    NaN
# 1     570283248301043712          negative   Southwest                    NaN
# 2     569684565838553088          negative    American                    NaN
# 3     569313126342123520          negative  US Airways                    NaN
# 4     569723892358467584          negative      United                    NaN
# ...                  ...               ...         ...                    ...
# 7681  569599532268449792          negative  US Airways                    NaN
# 7682  568475947617411072           neutral  US Airways                    NaN
# 7683  569392511732588544          negative  US Airways                    NaN
# 7684  568675083314552832          positive      United                    NaN
# 7685  568159085356384256          negative      United                    NaN
#
# ...

# %%
solutions = pd.read_csv('CorrectY.csv')

# %%
solutions
# Out:
#       Unnamed: 0 airline_sentiment
# 0              0          negative
# 1              1          negative
# 2              2          positive
# 3              3          positive
# 4              4           neutral
# ...          ...               ...
# 3289        3289           neutral
# 3290        3290          negative
# 3291        3291          negative
# 3292        3292          negative
# 3293        3293          negative
#
# [3294 rows x 2 columns]

# %%
solutions.rename(columns = {"Unnamed: 0" : "Id", "airline_sentiment" : "Expected"}, inplace = True)

# %%
solutions
# Out:
#         Id  Expected
# 0        0  negative
# 1        1  negative
# 2        2  positive
# 3        3  positive
# 4        4   neutral
# ...    ...       ...
# 3289  3289   neutral
# 3290  3290  negative
# 3291  3291  negative
# 3292  3292  negative
# 3293  3293  negative
#
# [3294 rows x 2 columns]

# %%
solutions.to_csv('correctY.csv')

# %%
solutions
# Out:
#       Unnamed: 0 airline_sentiment
# 0              0          negative
# 1              1          negative
# 2              2          positive
# 3              3          positive
# 4              4           neutral
# ...          ...               ...
# 3289        3289           neutral
# 3290        3290          negative
# 3291        3291          negative
# 3292        3292          negative
# 3293        3293          negative
#
# [3294 rows x 2 columns]

# %%
pred = pd.read_csv('predictions.csv', names = ['Predictions'])

# %%
pred.to_csv('predictions.csv')
